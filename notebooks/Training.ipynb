# %% [markdown]
# # Introduction

# %% [markdown]
# Follow tutorial https://www.youtube.com/watch?v=Mut_u40Sqz4

# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
repo_root, *_ = !git rev-parse --show-toplevel
# %cd {repo_root}
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/rubchume1/code/Users/rubchume/SalesReinforcer

# %%
from pathlib import Path

import gymnasium as gym 
from gymnasium import Env
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 
import numpy as np
import random
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ## Variables

# %%
log_path = Path("data/training/logs")
log_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Create environment

# %%
class UserFlowEnv(Env):
    def __init__(self):
        # Actions we can take, down, stay, up
        self.action_space = Discrete(3)
        # Temperature array
        self.observation_space = Box(0, 100, shape=(1,), dtype="int")
        # Set start temp
        self.state = 38 + random.randint(-3,3)
        # Set shower length
        self.shower_length = 60
        
    def _get_obs(self):
        return np.array([self.state])

    def _get_info(self):
        return {
            "degrees_from_ideal": np.abs(38) - self.state
        }
        
    def step(self, action):
        # Apply action
        # 0 -1 = -1 temperature
        # 1 -1 = 0 
        # 2 -1 = 1 temperature 
        self.state += action -1 
        # Reduce shower length by 1 second
        self.shower_length -= 1 
        
        # Calculate reward
        if self.state >=37 and self.state <=39: 
            reward =1 
        else: 
            reward = -1 
        
        # Check if shower is done
        if self.shower_length <= 0: 
            terminated = True
        else:
            terminated = False
        
        truncated = False
        return self._get_obs(), reward, terminated, truncated, self._get_info()

    def render(self):
        print(f"Temperature: {self.state}. Remaining Shower Length: {self.shower_length}")
    
    def reset(self, seed=0):
        self.state = 38 + random.randint(-3,3)
        self.shower_length = 60
        
        return self._get_obs(), self._get_info()

# %%
env = ShowerEnv()

# %%
check_env(ShowerEnv(), warn=True)

# %% [markdown]
# # Test environment

# %%
# episodes = 5
# for episode in range(1, episodes+1):
#     state = env.reset()
#     terminated = False
#     truncated = False
#     score = 0 
    
#     while not terminated and not truncated:
#         env.render()
#         action = env.action_space.sample()
#         state, reward, terminated, truncated, info = env.step(action)
#         score += reward
#     print('Episode:{} Score:{}'.format(episode, score))
# env.close()

# %% [markdown]
# # Train model

# %%
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# /anaconda/envs/salesreinforcercondavenv/lib/python3.10/site-packages/torch/cuda/__init__.py:138: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to data/training/logs/PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -27.1    |
# | time/              |          |
# |    fps             | 1018     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -27.2       |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007918391 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.000439    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.7        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00268    |
# |    value_loss           | 72.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25.2       |
# | time/                   |             |
# |    fps                  | 647         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005929317 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -0.000368   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.5        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00387    |
# |    value_loss           | 68.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -22.2        |
# | time/                   |              |
# |    fps                  | 610          |
# |    iterations           | 4            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0027863123 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.979       |
# |    explained_variance   | 0.00036      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.4         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 87.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -22.6       |
# | time/                   |             |
# |    fps                  | 589         |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008158669 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | -0.00626    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.3        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00834    |
# |    value_loss           | 85.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -23.4       |
# | time/                   |             |
# |    fps                  | 576         |
# |    iterations           | 6           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004940012 |
# |    clip_fraction        | 0.0368      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | -9.54e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.3        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 69.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -24.2       |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 7           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005197324 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.881      |
# |    explained_variance   | 0.0006      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.8        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00766    |
# |    value_loss           | 93.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 8           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004403079 |
# |    clip_fraction        | 0.0332      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.919      |
# |    explained_variance   | -0.00109    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.6        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000321   |
# |    value_loss           | 90.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -16.4        |
# | time/                   |              |
# |    fps                  | 553          |
# |    iterations           | 9            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0046939645 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.976       |
# |    explained_variance   | -0.00142     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31           |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 77.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -15.2       |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 10          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005241859 |
# |    clip_fraction        | 0.043       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | -0.000664   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.2        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00268    |
# |    value_loss           | 64.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -16        |
# | time/                   |            |
# |    fps                  | 550        |
# |    iterations           | 11         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00545152 |
# |    clip_fraction        | 0.0772     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.975     |
# |    explained_variance   | -0.0109    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 31         |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00424   |
# |    value_loss           | 70.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -14.5       |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 12          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007956257 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.974      |
# |    explained_variance   | -0.00255    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35          |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00897    |
# |    value_loss           | 80.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -16.3      |
# | time/                   |            |
# |    fps                  | 545        |
# |    iterations           | 13         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.00682564 |
# |    clip_fraction        | 0.0948     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.949     |
# |    explained_variance   | -0.0151    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.3       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.00507   |
# |    value_loss           | 74.9       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -13.4        |
# | time/                   |              |
# |    fps                  | 544          |
# |    iterations           | 14           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0042504147 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.95        |
# |    explained_variance   | -4.64e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.1         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 73           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -11.2       |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 15          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005280194 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | -0.000364   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.2        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00287    |
# |    value_loss           | 87.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -8.16        |
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 16           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0038392157 |
# |    clip_fraction        | 0.0646       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.959       |
# |    explained_variance   | 0.000782     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.7         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00362     |
# |    value_loss           | 65.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -7.34        |
# | time/                   |              |
# |    fps                  | 540          |
# |    iterations           | 17           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0079832245 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.944       |
# |    explained_variance   | -0.00486     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.4         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00865     |
# |    value_loss           | 65.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -4.4         |
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 18           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0072681955 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.925       |
# |    explained_variance   | -0.0252      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.5         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0109      |
# |    value_loss           | 58           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 19          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004430365 |
# |    clip_fraction        | 0.0752      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.931      |
# |    explained_variance   | -0.000353   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30          |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00224    |
# |    value_loss           | 63.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 7.32         |
# | time/                   |              |
# |    fps                  | 537          |
# |    iterations           | 20           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0051634614 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.923       |
# |    explained_variance   | -0.005       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.7         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00616     |
# |    value_loss           | 66.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 10.2        |
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 21          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007987542 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.912      |
# |    explained_variance   | 0.000884    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29          |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 52.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 535         |
# |    iterations           | 22          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008909481 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | -0.0044     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.7        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 61.9        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | 14        |
# | time/                   |           |
# |    fps                  | 535       |
# |    iterations           | 23        |
# |    time_elapsed         | 87        |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.0072353 |
# |    clip_fraction        | 0.0944    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.908    |
# |    explained_variance   | -0.00122  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 27.1      |
# |    n_updates            | 290       |
# |    policy_gradient_loss | -0.00642  |
# |    value_loss           | 59.2      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 18.3        |
# | time/                   |             |
# |    fps                  | 535         |
# |    iterations           | 24          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007197013 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | -0.000728   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.3        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0073     |
# |    value_loss           | 51.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 22.7         |
# | time/                   |              |
# |    fps                  | 535          |
# |    iterations           | 25           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0069541456 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.895       |
# |    explained_variance   | 0.000258     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.5         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00546     |
# |    value_loss           | 50.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 22.1        |
# | time/                   |             |
# |    fps                  | 535         |
# |    iterations           | 26          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005694964 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.878      |
# |    explained_variance   | 0.00016     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.6        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.000241    |
# |    value_loss           | 46.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 22.9        |
# | time/                   |             |
# |    fps                  | 535         |
# |    iterations           | 27          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.015013186 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | 0.00143     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.6        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 51.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 25.5        |
# | time/                   |             |
# |    fps                  | 534         |
# |    iterations           | 28          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009822923 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | 0.00374     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.3        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 56.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 30.1         |
# | time/                   |              |
# |    fps                  | 534          |
# |    iterations           | 29           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0070475005 |
# |    clip_fraction        | 0.177        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.902       |
# |    explained_variance   | -0.00268     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.1         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.00817      |
# |    value_loss           | 52.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 35.3        |
# | time/                   |             |
# |    fps                  | 526         |
# |    iterations           | 30          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011917403 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.895      |
# |    explained_variance   | 0.00091     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.8        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 58.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 35.6        |
# | time/                   |             |
# |    fps                  | 519         |
# |    iterations           | 31          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011825165 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.884      |
# |    explained_variance   | 0.00056     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.9        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00126     |
# |    value_loss           | 53.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 40          |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 32          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.012730719 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | 0.000307    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.6        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00292    |
# |    value_loss           | 62          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.4        |
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 33          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.005624309 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.887      |
# |    explained_variance   | -0.000192   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.6        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00139    |
# |    value_loss           | 67.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.9        |
# | time/                   |             |
# |    fps                  | 503         |
# |    iterations           | 34          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.013859398 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | -2.41e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.1        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00508     |
# |    value_loss           | 68.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.8        |
# | time/                   |             |
# |    fps                  | 499         |
# |    iterations           | 35          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.014926688 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.898      |
# |    explained_variance   | 1.07e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.4        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00833     |
# |    value_loss           | 73          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.9        |
# | time/                   |             |
# |    fps                  | 494         |
# |    iterations           | 36          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012569756 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.867      |
# |    explained_variance   | 2.04e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.1        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00506     |
# |    value_loss           | 78.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.8        |
# | time/                   |             |
# |    fps                  | 488         |
# |    iterations           | 37          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.014115568 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.863      |
# |    explained_variance   | -9.06e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.6        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00475     |
# |    value_loss           | 82          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 47.3       |
# | time/                   |            |
# |    fps                  | 484        |
# |    iterations           | 38         |
# |    time_elapsed         | 160        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.00774141 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.89      |
# |    explained_variance   | 2.31e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 41.8       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.00426    |
# |    value_loss           | 78.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.3        |
# | time/                   |             |
# |    fps                  | 472         |
# |    iterations           | 39          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.010498345 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | -1.32e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37          |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00708     |
# |    value_loss           | 86.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.6        |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 40          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.017191876 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.857      |
# |    explained_variance   | -2.68e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.2        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 86.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 36.9        |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 41          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.019762121 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | -2.84e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.3        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.000957    |
# |    value_loss           | 81          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 34.8         |
# | time/                   |              |
# |    fps                  | 470          |
# |    iterations           | 42           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0153073715 |
# |    clip_fraction        | 0.167        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.849       |
# |    explained_variance   | -5.96e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.7         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 68.9         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 37         |
# | time/                   |            |
# |    fps                  | 471        |
# |    iterations           | 43         |
# |    time_elapsed         | 186        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.01106446 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.819     |
# |    explained_variance   | -0.000208  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 39.4       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0103    |
# |    value_loss           | 70.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.5        |
# | time/                   |             |
# |    fps                  | 473         |
# |    iterations           | 44          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.016691813 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.812      |
# |    explained_variance   | -0.000114   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.4        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.000608    |
# |    value_loss           | 65.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.6        |
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 45          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008775225 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.78       |
# |    explained_variance   | -4.17e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.8        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00865     |
# |    value_loss           | 73.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 49.6         |
# | time/                   |              |
# |    fps                  | 474          |
# |    iterations           | 46           |
# |    time_elapsed         | 198          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0076574166 |
# |    clip_fraction        | 0.13         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.755       |
# |    explained_variance   | 8.34e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.6         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | 0.00717      |
# |    value_loss           | 80.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 50.2         |
# | time/                   |              |
# |    fps                  | 475          |
# |    iterations           | 47           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0077196774 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.73        |
# |    explained_variance   | 7.03e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.7         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | 0.00129      |
# |    value_loss           | 90.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.8        |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 48          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006696467 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.732      |
# |    explained_variance   | 2.32e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.9        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.00671     |
# |    value_loss           | 89.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.5        |
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 49          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.008799786 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.74       |
# |    explained_variance   | 4.77e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.8        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | 0.00541     |
# |    value_loss           | 94          |
# -----------------------------------------

# %%
evaluate_policy(model, env, n_eval_episodes=100, render=True, return_episode_rewards=True)
# Out:
# ([60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   58.0,
#   58.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   58.0,
#   60.0,
#   60.0,
#   60.0,
#   58.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   58.0,
#   60.0,
#   58.0,
#   60.0,
#   60.0,
#   58.0,
#   60.0,
#   60.0,
#   58.0,
#   60.0,
#   58.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   58.0,
#   60.0,
#   58.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   58.0,
#   60.0,
#   60.0,
#   60.0,
#   58.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   58.0,
#   60.0,
#   60.0,
#   60.0,
#   58.0,
#   60.0,
#   60.0,
#   58.0,
#   60.0,
#   58.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   58.0,
#   58.0,
#   58.0,
#   58.0,
#   58.0,
#   60.0,
#   58.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0,
#   60.0],
#  [60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60])

# %%
from azureml.tensorboard import Tensorboard

# The TensorBoard constructor takes an array of jobs, so be sure and pass it in as a single-element array here
tb = Tensorboard([], local_root=log_path, port=6006)

# If successful, start() returns a string with the URI of the instance.
tb.start()
# Out:
# https://rubchume1-6006.westeurope.instances.azureml.ms
# 'https://rubchume1-6006.westeurope.instances.azureml.ms'
